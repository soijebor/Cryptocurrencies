# %%
import pandas as pd

# %%
file_path = "/Users/sonia_ij/Desktop/Data Analysis Class/Module 18/Cryptocurrencies/resources/iris.csv"
iris_df = pd.read_csv(file_path)
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
new_iris_df = iris_df.drop(['class'], axis =1)
new_iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
#Skill drill 18.2.2
# Reorder columns to sepal_length, petal_length, sepal_width, petal_width
cols_df = new_iris_df[['sepal_length', 'petal_length', 'sepal_width', 'petal_width']]
cols_df
# Out:
#      sepal_length  petal_length  sepal_width  petal_width
# 0             5.1           1.4          3.5          0.2
# 1             4.9           1.4          3.0          0.2
# 2             4.7           1.3          3.2          0.2
# 3             4.6           1.5          3.1          0.2
# 4             5.0           1.4          3.6          0.2
# ..            ...           ...          ...          ...
# 145           6.7           5.2          3.0          2.3
# 146           6.3           5.0          2.5          1.9
# 147           6.5           5.2          3.0          2.0
# 148           6.2           5.4          3.4          2.3
# 149           5.9           5.1          3.0          1.8
#
# [150 rows x 4 columns]

# %%
# preprocessed DataFrame is saved on a new CSV file for future use
output_file_path = "/Users/sonia_ij/Desktop/Data Analysis Class/Module 18/Cryptocurrencies/resources/new_iris_data.csv"
new_iris_df.to_csv(output_file_path, index=False)

# %% [markdown]
# ## ***Preprocessing Data With Pandas***

# %%
# Data loading
file_path = "/Users/sonia_ij/Desktop/Data Analysis Class/Module 18/Cryptocurrencies/resources/shopping_data.csv"
df_shopping = pd.read_csv(file_path, encoding="ISO-8859-1")
df_shopping.head(5)
# Out:
#    CustomerID Card Member   Age  Annual Income  Spending Score (1-100)
# 0           1         Yes  19.0          15000                    39.0
# 1           2         Yes  21.0          15000                    81.0
# 2           3          No  20.0          16000                     6.0
# 3           4          No  23.0          16000                    77.0
# 4           5          No  31.0          17000                    40.0

# %%
# Columns
df_shopping.columns
# Out:
# Index(['CustomerID', 'Card Member', 'Age', 'Annual Income',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
# List dataframe data types
df_shopping.dtypes
# Out:
# CustomerID                  int64
# Card Member                object
# Age                       float64
# Annual Income               int64
# Spending Score (1-100)    float64
# dtype: object

# %%
# Find null values
for column in df_shopping.columns:
    print(f"Column {column} has {df_shopping[column].isnull().sum()} null values")
# Out:
# Column CustomerID has 0 null values
# Column Card Member has 2 null values
# Column Age has 2 null values
# Column Annual Income has 0 null values
# Column Spending Score (1-100) has 1 null values

# %%
# Drop null rows
df_shopping = df_shopping.dropna()

# %%
# Find duplicate entries
print(f"Duplicate entries: {df_shopping.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
# Remove the CustomerID Column
df_shopping.drop(columns=["CustomerID"], inplace=True)
df_shopping.head()
# Out:
#   Card Member   Age  Annual Income  Spending Score (1-100)
# 0         Yes  19.0          15000                    39.0
# 1         Yes  21.0          15000                    81.0
# 2          No  20.0          16000                     6.0
# 3          No  23.0          16000                    77.0
# 4          No  31.0          17000                    40.0

# %%
# Transform String column
def change_string(member):
    if member == "Yes":
        return 1
    else:
        return 0
    
df_shopping["Card Member"] = df_shopping["Card Member"].apply(change_string)
df_shopping.head()
# Out:
#    Card Member   Age  Annual Income  Spending Score (1-100)
# 0            1  19.0          15000                    39.0
# 1            1  21.0          15000                    81.0
# 2            0  20.0          16000                     6.0
# 3            0  23.0          16000                    77.0
# 4            0  31.0          17000                    40.0

# %%
# Tranform annual income
df_shopping["Annual Income"] = df_shopping["Annual Income"] / 1000
df_shopping.head()
# Out:
#    Card Member   Age  Annual Income  Spending Score (1-100)
# 0            1  19.0          0.015                    39.0
# 1            1  21.0          0.015                    81.0
# 2            0  20.0          0.016                     6.0
# 3            0  23.0          0.016                    77.0
# 4            0  31.0          0.017                    40.0

# %%
RenamedColumns_df = df_shopping.rename(columns = {'Card Member':'CardMember', 'Age':'Age', 'Annual Income':'AnnualIncome', 'Spending Score (1-100)':'SpendingScore'})
RenamedColumns_df
# Out:
#      CardMember   Age  AnnualIncome  SpendingScore
# 0             1  19.0          15.0           39.0
# 1             1  21.0          15.0           81.0
# 2             0  20.0          16.0            6.0
# 3             0  23.0          16.0           77.0
# 4             0  31.0          17.0           40.0
# ..          ...   ...           ...            ...
# 198           0  35.0         120.0           79.0
# 199           0  45.0         126.0           28.0
# 200           1  32.0         126.0           74.0
# 201           1  32.0         137.0           18.0
# 202           1  30.0         137.0           83.0
#
# [200 rows x 4 columns]

# %%
# Saving cleaned data
file_path = "/Users/sonia_ij/Desktop/Data Analysis Class/Module 18/Cryptocurrencies/resources/shopping_data_cleaned.csv"
df_shopping.to_csv(file_path, index=False)

# %%
# Saving Renamed cleaned data
file_path = "/Users/sonia_ij/Desktop/Data Analysis Class/Module 18/Cryptocurrencies/resources/shopping_data_Renamed_cleaned.csv"
RenamedColumns_df.to_csv(file_path, index=False)
